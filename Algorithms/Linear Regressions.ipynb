# %%
from statistics import mean
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
cgpa=pd.read_csv(r'C:\Users\PRIYANSHU PANDEY\Downloads\cgpa.csv')
z=cgpa.head(500)

del z['rollno']
w=np.array(z,dtype=np.float64)
#=np.array(z[:,:1])
#=np.array(z[:,1:])
#.shape
x=w[:,0]
y=w[:,1]

def best_slope_intercept(x,y):
    m=((mean(x)*mean(y))-mean(x*y))/((mean(x)*mean(x))-mean(x*x))
    c=mean(y)-mean(x)*m
    return m,c
m,c=best_slope_intercept(x,y)

y_regrression_line= [(m*x)+c for i in range(len(x))]
plt.scatter(x,y)
plt.plot(x,y_regrression_line)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression
algo1=LinearRegression()
algo1.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x.shape
#algo1.coef_
# Out:
# (100, 1)

# %%
algo1.intercept_
# Out:
# 1.9999999999999973

# %%
algo1.coef_[0]+(0.2565465479841516)
# Out:
# 1.2565465479841518

# %%
import matplotlib.pyplot as plt

m=algo1.coef_[0]+(0.2565465479841516)
c=algo1.intercept_

x_line = np.arange(0,10,0.1)
y_line = m*x_line + c
plt.plot(x_line,y_line)
plt.scatter(x_test,y_test)
plt.show()

# %%
import pandas as pd
import numpy as np
 
cgpa=pd.read_csv(r'C:\Users\PRIYANSHU PANDEY\Downloads\cgpa.csv')
z=cgpa.head(100)

del z['rollno']
z.describe()
z.columns=[0,1]
v=z[0]*0.85644654
p=np.array(z)
y=np.array(v)
x=p[:,0]

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y,test_size=0.3)

# %%
def fit(x_train, y_train):
    num = (x_train*y_train).mean() -x_train.mean() * y_train.mean()
    den = (x_train**2).mean() -x_train.mean()**2
    m =num/den
    c = y_train.mean() -m * x_train.mean()
    return m,c

def predict(x,m,c):
    return m*x + c

def score(y_truth, y_pred):
    u = ((y_truth - y_pred)**2).sum()
    v =((y_truth-y_truth.mean())**2).sum()
    return 1-u/v

def cost(x,y,m,c):
    return ((y-m*x-c)**2).mean()

# %%
m,c = fit(x_train,y_train)

# test data
y_test_pred = predict(x_test,m,c)
print('TEST SCORE',score(y_test,y_test_pred))

# train data
y_train_pred = predict(x_train,m,c)
print('TEST SCORE',score(y_train,y_train_pred))
print('M , c',m,c)
print('Cost on Training Data',cost(x_train,y_train,m,c))
print('Cost on Training Data',cost(x_train,y_train,m,c+1))
print('Cost on Training Data',cost(x_train,y_train,m+1,c))
print('Cost on Training Data',cost(x_train,y_train,m+1,c+1))
# Out:
# TEST SCORE -24.254402370001444
# TEST SCORE -74.0
# M , c 0.0 9.507382374648897
# Cost on Training Data 2.022986239159844
# Cost on Training Data 3.0229862391598443
# Cost on Training Data 60.406762597508596
# Cost on Training Data 76.4215273468064

# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression

data=np.genfromtxt('data.csv',delimiter=',')

x=data[:,0]
y=data[:,1]

x.shape

from sklearn import model_selection
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y,test_size=0.3)

def fit(x_train, y_train):
    num = (x_train*y_train).mean() -x_train.mean() * y_train.mean()
    den = (x_train**2).mean() -x_train.mean()**2
    m =num/den
    c = y_train.mean() -m * x_train.mean()
    return m,c

def predict(x,m,c):
    return m*x + c

def score(y_truth, y_pred):
    u = ((y_truth - y_pred)**2).sum()
    v =((y_truth-y_truth.mean())**2).sum()
    return 1-u/v

def cost(x,y,m,c):
    return ((y-m*x-c)**2).mean()
m,c = fit(x_train,y_train)

# test data
y_test_pred = predict(x_test,m,c)
print('TEST SCORE',score(y_test,y_test_pred))

# train data
y_train_pred = predict(x_train,m,c)
print('TEST SCORE',score(y_train,y_train_pred))
print('M , c',m,c)
print('Cost on Training Data',cost(x_train,y_train,m,c))

print(x_test)
# Out:
# TEST SCORE 0.6372385256266777
# TEST SCORE 0.5820947857697278
# M , c 1.2884798086007498 9.163950320826693
# Cost on Training Data 120.27892981149286
# [40.59953838 50.07314563 45.61864377 55.80573336 43.31828263 60.29732685
#  50.13548549 38.00548801 33.09383174 49.20388754 46.68222865 43.87061265
#  68.31936082 38.11982403 54.35163488 57.78822399 58.16454011 64.70713867
#  45.44053073 38.81681754 49.23976534 36.93007661 48.10504169 35.67809389
#  44.68719623 44.55560838 56.86890066 57.36205213 51.0887199  59.04974121]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data.csv')
df.head()
# Out:
#    32.502345269453031  31.70700584656992
# 0           53.426804          68.777596
# 1           61.530358          62.562382
# 2           47.475640          71.546632
# 3           59.813208          87.230925
# 4           55.142188          78.211518

# %%
import numpy as np
np.zeroes(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-734df9f10d69> in <module>()
#       1 import numpy as np
# ----> 2 np.zeroes(10)
#
# AttributeError: module 'numpy' has no attribute 'zeroes'
